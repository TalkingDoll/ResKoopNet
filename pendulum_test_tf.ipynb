# %%
import numpy as np
from numpy import linalg as la
from numpy import *
import numpy.linalg as la

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from scipy.io import loadmat
import os
import scipy.io as sio

from koopman_pseudospec_qr import KoopPseudoSpecQR
from matplotlib.colors import ListedColormap, BoundaryNorm

# Load the specified MAT-file using scipy.io.loadmat()
file_path = 'data/pendulum_data/data_pendulum_90.mat'
data_pendulum = loadmat(file_path)


import tensorflow as tf
print("TensorFlow version:", tf.__version__)
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# TensorFlow version: 2.10.0
# GPU is available

# %%
# Assuming the loaded MAT-file is named data_pendulum_90
X = data_pendulum['DATA_X']
Y = data_pendulum['DATA_Y']

print(X.shape)
# Out:
# (90000, 2)

# %%
len_all = X.shape[0]
data_x_train = X[:int(0.7*len_all)]
data_x_valid = X[int(0.7*len_all)+1:]

data_y_train = Y[:int(0.7*len_all)]
data_y_valid = Y[int(0.7*len_all)+1:]

data_train = [data_x_train, data_y_train]
data_valid = [data_x_valid, data_y_valid]

# %%
### Train the basis using NN-resDMD
### Calculate for chosen number of basis ###
# Results from solver_resdmd_tf
from solver_resdmd_tf import KoopmanNN, KoopmanSolver

dic_size = 300

basis_function = KoopmanNN(layer_sizes=[400,400,400], n_psi_train=dic_size-3) # basis number would be 300

solver = KoopmanSolver(dic=basis_function,
                         target_dim=np.shape(data_x_train)[-1],
                         reg=0.1)
solver.build(data_train=data_train,
             data_valid=data_valid,
             epochs=30,
             batch_size=50000,
             lr=1e-5,
             log_interval=10,
             lr_decay_factor=.8)

# Results from solver_resdmd_tf
evalues = solver.eigenvalues.T
efuns = solver.eigenfunctions(X)
kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver.get_Psi_X().numpy()
Psi_Y = solver.get_Psi_Y().numpy()
Koopman_matrix_K = solver.K.numpy()
outputs = {
    'efuns': efuns,
    'evalues': evalues,
    'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    'K': Koopman_matrix_K,
    'Psi_X': Psi_X,
    'Psi_Y': Psi_Y,
}
# Out:
# Outer Epoch 1/30
# Epoch 1/2
# 2/2 [==============================] - 5s 2s/step - loss: 2.1031e-08 - val_loss: 1.0846e-07
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.2911e-06 - val_loss: 1.2154e-05
# Outer Epoch 2/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 1.2121e-05 - val_loss: 3.4069e-06
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 4.5609e-06 - val_loss: 5.1124e-06
# Outer Epoch 3/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 4.8082e-06 - val_loss: 4.4166e-06
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 4.6769e-06 - val_loss: 1.9112e-06
# Outer Epoch 4/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.0952e-06 - val_loss: 3.0094e-06
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 3.0449e-06 - val_loss: 1.3536e-06
# Outer Epoch 5/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 1.4873e-06 - val_loss: 1.9282e-06
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 1.9408e-06 - val_loss: 8.6219e-07
# Outer Epoch 6/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 9.9186e-07 - val_loss: 1.2857e-06
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 1.2504e-06 - val_loss: 6.6549e-07
# Outer Epoch 7/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 7.7367e-07 - val_loss: 7.3381e-07
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 7.1123e-07 - val_loss: 6.0251e-07
# Outer Epoch 8/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 6.5639e-07 - val_loss: 3.6240e-07
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 3.7821e-07 - val_loss: 4.9081e-07
# Outer Epoch 9/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 4.9619e-07 - val_loss: 2.3880e-07
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.6646e-07 - val_loss: 3.0784e-07
# Outer Epoch 10/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 3.0706e-07 - val_loss: 1.9845e-07
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.1519e-07 - val_loss: 1.9181e-07
# Outer Epoch 11/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 1.9294e-07 - val_loss: 1.6073e-07
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 1.6866e-07 - val_loss: 1.1821e-07
# Outer Epoch 12/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 1.2295e-07 - val_loss: 1.2838e-07
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 1.2787e-07 - val_loss: 8.4068e-08
# Outer Epoch 13/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 9.0855e-08 - val_loss: 8.2615e-08
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 8.2570e-08 - val_loss: 7.5356e-08
# Outer Epoch 14/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 7.6561e-08 - val_loss: 5.7986e-08
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 6.0116e-08 - val_loss: 5.3696e-08
# Outer Epoch 15/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 5.4149e-08 - val_loss: 5.1639e-08
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 5.1127e-08 - val_loss: 4.2603e-08
# Outer Epoch 16/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 4.3524e-08 - val_loss: 3.7734e-08
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 3.7833e-08 - val_loss: 3.7898e-08
# Outer Epoch 17/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 3.7173e-08 - val_loss: 3.3333e-08
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 3.3302e-08 - val_loss: 2.9447e-08
# Outer Epoch 18/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.9511e-08 - val_loss: 2.9814e-08
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.8915e-08 - val_loss: 2.8704e-08
# Outer Epoch 19/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.8153e-08 - val_loss: 2.4732e-08
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.4693e-08 - val_loss: 2.5614e-08
# Outer Epoch 20/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.4692e-08 - val_loss: 2.5902e-08
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.4977e-08 - val_loss: 2.3169e-08
# Outer Epoch 21/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.2857e-08 - val_loss: 2.2704e-08
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.2068e-08 - val_loss: 2.3707e-08
# Outer Epoch 22/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.2684e-08 - val_loss: 2.2736e-08
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.2052e-08 - val_loss: 2.1585e-08
# Outer Epoch 23/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.1004e-08 - val_loss: 2.2081e-08
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.1205e-08 - val_loss: 2.2220e-08
# Outer Epoch 24/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.1337e-08 - val_loss: 2.1512e-08
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.0793e-08 - val_loss: 2.1275e-08
# Outer Epoch 25/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.0515e-08 - val_loss: 2.1455e-08
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.0607e-08 - val_loss: 2.1400e-08
# Outer Epoch 26/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.0564e-08 - val_loss: 2.1134e-08
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.0346e-08 - val_loss: 2.1038e-08
# Outer Epoch 27/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.0244e-08 - val_loss: 2.1094e-08
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.0260e-08 - val_loss: 2.1079e-08
# Outer Epoch 28/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.0250e-08 - val_loss: 2.1000e-08
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.0181e-08 - val_loss: 2.0957e-08
# Outer Epoch 29/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.0141e-08 - val_loss: 2.0933e-08
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.0113e-08 - val_loss: 2.0928e-08
# Outer Epoch 30/30
# Epoch 1/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.0101e-08 - val_loss: 2.0904e-08
# Epoch 2/2
# 2/2 [==============================] - 3s 1s/step - loss: 2.0076e-08 - val_loss: 2.0868e-08

# %%
# ## Plot eigenvalues in a unit circle
# # Assuming evalues is a numpy array of complex numbers
# real_parts = evalues.real
# imag_parts = evalues.imag

# # Create the plot
# plt.figure(figsize=(8, 6))
# plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# # Draw a unit circle for reference
# theta = np.linspace(0, 2*np.pi, 100)
# plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

# plt.title('Eigenvalues in Unit Circle')
# plt.xlabel('Real Part')
# plt.ylabel('Imaginary Part')
# plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
# plt.grid(True, which='both', linestyle='--', linewidth=0.5)
# plt.legend()
# plt.show()

# %%
# import os
# import scipy.io as sio

# # Define the folder path
# folder_path = 'data/pendulum_data'
# # Create the folder if it doesn't exist
# os.makedirs(folder_path, exist_ok=True)

# # Save the outputs to a .mat file named according to the number of basis functions, inside the specified folder
# file_path = os.path.join(folder_path, f'pendulum_90_resdmd_{N_dict}basis.mat')
# sio.savemat(file_path, outputs)
# print(f'Saved outputs for n_psi_train={N_dict} to {file_path}')

# %%
## Plot the pseudospectrum
# m= Psi_X.shape[0]
print (m)
W = np.ones((m, 1), dtype= np.double)
G= np.dot(Psi_X.T , Psi_X)
print (G.shape)
print ('cond(G) is:',la.cond(G))
x_pts= arange (-1.5, 1.5+0.05, 0.05)
y_pts=x_pts
print (x_pts.shape)
x_pts_mesh,y_pts_mesh= meshgrid (x_pts, y_pts)
z_pts= x_pts_mesh + 1j*y_pts_mesh
z_pts= z_pts.ravel()
RES= KoopPseudoSpecQR(Psi_X,Psi_Y,W,z_pts)
RES= RES.reshape (x_pts_mesh.shape)

lower_bound = 1e-16#; % Example lower bound
#Find indices where the real part of RES is zero
zero_real_indices =nonzero (np.real(RES)==0)
#% Replace only the real part of RES elements that are zero with the lower bound
RES[zero_real_indices] = lower_bound + imag(RES[zero_real_indices]) * 1j


# Plot 1st type of image
plt.figure(figsize=(4, 4))  # Set the plot size (width, height) in inches
v= array ([0.25, 1e-64])
plt.contourf(x_pts_mesh,y_pts_mesh,log10(1/real(RES)),levels= log10(1/v))
plt.contour(x_pts_mesh,y_pts_mesh,log10(1/real(RES)),levels= log10(1/v))
circle_phi= arange (0, 2*np.pi ,2*np.pi/1000 )
plt.plot (np.cos(circle_phi), np.sin(circle_phi), color= 'red')
plt.title(f'N_K = {dic_size}')
plt.grid()
plt.show()


# Set the threshold
threshold = 0.25
# Create a custom colormap
colors = ['lightgreen', 'white']
cmap = ListedColormap(colors)
# Define the boundaries for the colormap
boundaries = [np.min(np.real(RES)), threshold, np.max(np.real(RES))]
norm = BoundaryNorm(boundaries, cmap.N, clip=True)
# Plot 2nd type of image
plt.figure(figsize=(4, 4))  # Set the plot size (width, height) in inches
plt.pcolormesh(x_pts_mesh, y_pts_mesh, np.real(RES), shading='gouraud', cmap=cmap, norm=norm)
# plt.colorbar()  # Add colorbar
plt.title(f'N_K = {dic_size}')
plt.show()

# %%
### Calculate for multiple numbers of basis ###

from solver_resdmd_tf import KoopmanNN, KoopmanSolver
# from solver_resdmd_2_tf import KoopmanNN, KoopmanSolver

dic_size = [25,50,100,150,200,250,300] # basis number would be 25, 50, 100, 150, 200, 250, 300

for n_psi in dic_size:
    # Initialize the basis function with the current value of n_psi_train
    basis_function = KoopmanNN(layer_sizes=[300,300,300], n_psi_train=n_psi-3)

    # Initialize the solver with the basis function and other parameters
    solver = KoopmanSolver(dic=basis_function,
                             target_dim=np.shape(data_x_train)[-1],
                             reg=0.1)
    # Build the solver with the specified training and validation data
    solver.build(data_train=data_train,
                 data_valid=data_valid,
                 epochs=300,
                 batch_size=50000,
                 lr=1e-6,
                 log_interval=10,
                 lr_decay_factor=.8)

    # Assuming the user has these functions or similar ones defined in their environment
    evalues = solver.eigenvalues.T
    efuns = solver.eigenfunctions(X)
    kpm_modes = solver.compute_mode().T
    N_dict = np.shape(evalues)[0]
    Koopman_matrix_K = solver.K.numpy()    
    Psi_X = solver.get_Psi_X().numpy()
    Psi_Y = solver.get_Psi_Y().numpy()
    outputs = {
        'efuns': efuns,
        'evalues': evalues,
        'kpm_modes': kpm_modes,
        'N_dict': N_dict,
        'K': Koopman_matrix_K,
        'Psi_X': Psi_X,
        'Psi_Y': Psi_Y,
        # 'Psi_X2': Psi_X2,
        # 'Psi_Y2': Psi_Y2,
        # "Jacobian": jacobian,  # Uncomment if needed
        # "Hessian": hessian,    # Uncomment if needed
    }

    folder_path = 'data/pendulum_data'  # Adjust the path as needed if you want a different location
    os.makedirs(folder_path, exist_ok=True)
    # Save the outputs to a .mat file named according to the number of basis functions, inside the "data" folder
    file_path = os.path.join(folder_path, f'pendulum_90_resdmd_{N_dict}basis.mat')
    sio.savemat(file_path, outputs)
    print(f'Saved outputs for n_psi_train={n_psi} to {file_path}')
